# %% [markdown]
# <a href="https://colab.research.google.com/github/aosorioca-boop/programacionCientifica/blob/AlexaOsorio/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 2
b = 3

print(a+b)
# Out:
# 5
